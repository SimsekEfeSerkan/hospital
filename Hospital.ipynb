# %%
class hospital:
    
    def __init__(self, name, surname , age,):
        self.name = name
        self.surname = surname
        self.age = age
    def save(name, surname, age):
        open('hospital.txt', 'a').write(name + ' ' + surname + ' ' + age + '\n')
    def read():
        with open('hospital.txt', 'r') as f:
            for line in f:
                print(line)
    def delete():
        with open('hospital.txt', 'w') as f:
            f.write('')
    def save_doctor(name, surname, age):
        open('doctor.txt', 'a').write(name + ' ' + surname + ' ' + age + '\n')
    def read_doctor():
        with open('doctor.txt', 'r') as f:
            for line in f:
                print(line)
    def delete_doctor():
        with open('doctor.txt', 'w') as f:
            f.write('')
    def to_apply(name, surname):
            with open('doctor.txt') as info:
                        veri = info.read()
            if name and surname in veri:
                        print("Found :",name,surname)
            else:
                        print("Not found")
    def search(name, surname):
            name = input("Enter your patient's name: ")
            surname = input("Enter your patient's surname: ")
            with open('hospital.txt') as info:
                        veri = info.read()
            if name and surname in veri:
                        print("Found :",name,surname)
            else:
                        print("Not found")
a = 0
while a != 10:
    x = input("what do you want to do?\n1. Save\n2. Read\n3. Delete\n4. Save doctor\n5. Read doctor\n6. Delete doctor\n7. To apply\n8. Search\n9. Exit\n")
    if x == '1':
            name = input("Name: ")
            surname = input("Surname: ")
            age = input("Age: ")
            hospital.save(name, surname, age)
    elif x == '2':
            hospital.read()
    elif x == '3':
            hospital.delete()
    elif x == '4':
            name = input("Name: ")
            surname = input("Surname: ")
            age = input("Age: ")
            hospital.save_doctor(name, surname, age)
    elif x == '5':
            hospital.read_doctor()
    elif x == '6':
            hospital.delete_doctor()
    elif x == '7':
        name = input("Enter your doctor's name: ")
        surname = input("Enter your doctor's surname: ")
        hospital.to_apply(name, surname)
        hospital.search(name, surname)
        print("application successful")
    elif x == '8':
            name = input("Name: ")
            surname = input("Surname: ")
            age = input("Age: ")
            hospital.search(name, surname, age)
    elif x == '9':
            print("Goodbye")
            break
    else:
        print("Invalid input")
# Out:
# Goodbye
